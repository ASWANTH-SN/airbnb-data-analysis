# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('/content/Airbnb_Open_Data.csv', low_memory= False)

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  19-10-2021               0.21                4.0
# 1              45.0  21-05-2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0  05-07-2019               4.64                4.0
# 4               9.0  19-11-2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %%
df.info()
df.duplicated().value_counts()
df[df['neighbourhood group']== 'brookln']
df.drop_duplicates(inplace=True)
df.drop(['house_rules', 'license'], axis = 1, inplace= True)
df['price'] = df ['price'].str.replace('$','', regex= False)
df['service fee'] = df['service fee'].str.replace('$','', regex= False)
df['price'] =df['price'].str.replace(',','', regex= False)
df['service fee'] = df ['service fee'].str.replace(',','', regex= False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36600 entries, 0 to 36599
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36600 non-null  int64
#  1   NAME                            36483 non-null  object
#  2   host id                         36600 non-null  int64
#  3   host_identity_verified          36442 non-null  object
#  4   host name                       36368 non-null  object
#  5   neighbourhood group             36573 non-null  object
#  6   neighbourhood                   36584 non-null  object
#  7   lat                             36592 non-null  float64
#  8   long                            36592 non-null  float64
#  9   country                         36513 non-null  object
#  10  country code                    36521 non-null  object
#  11  instant_bookable                36521 non-null  object
#  12  cancellation_policy             36550 non-null  object
#  13  room type                       36600 non-null  object
#  14  Construction year               36454 non-null  float64
#  15  price                           36502 non-null  object
#  16  service fee                     36514 non-null  object
#  17  minimum nights                  36403 non-null  float64
#  18  number of reviews               36566 non-null  float64
#  19  last review                     30744 non-null  object
#  20  reviews per month               30758 non-null  float64
#  21  review rate number              36477 non-null  float64
#  22  calculated host listings count  36517 non-null  float64
#  23  availability 365                36422 non-null  float64
#  24  house_rules                     24454 non-null  object
#  25  license                         1 non-null      object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 7.3+ MB

# %%
df.rename(columns = {
    'price': 'price_$',
    'service fee': 'service_fee_$'
    }, inplace =True)
df.dropna(inplace=True)
df['price_$']=df['price_$'].astype(float)
df['service_fee_$'] =df['service_fee_$'].astype(float)



df['id'] = df ['id'].astype(str)

df['host id'] = df['host id'].astype(str)

df['last review'] = pd.to_datetime(df['last review'])

df ['Construction year']= df['Construction year'].astype(int)
# Out:
# /tmp/ipython-input-715059421.py:15: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['last review'] = pd.to_datetime(df['last review'])

# %%
df.loc[df['neighbourhood group'] == 'brookin', 'neighbourhood group'] = 'Brooklyn'


df=df.drop(df[df['availability 365'] > 500].index)

# %%
df.duplicated().value_counts()
df.info()
df.describe()
property_types = df['room type'].value_counts().to_frame()

property_types
room_type_bar = plt.bar(property_types.index, property_types.loc[:, "count"]);

plt.bar_label(room_type_bar, labels = property_types.loc[:, "count"], padding = 4);

plt.ylim([0,50000]);

plt.xlabel('Room Type');

plt.ylabel('Room Type Count');

plt.title('Property Types and their count in the Dataset');
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29602 entries, 0 to 36599
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              29602 non-null  object
#  1   NAME                            29602 non-null  object
#  2   host id                         29602 non-null  object
#  3   host_identity_verified          29602 non-null  object
#  4   host name                       29602 non-null  object
#  5   neighbourhood group             29602 non-null  object
#  6   neighbourhood                   29602 non-null  object
#  7   lat                             29602 non-null  float64
#  8   long                            29602 non-null  float64
#  9   country                         29602 non-null  object
#  10  country code                    29602 non-null  object
#  11  instant_bookable                29602 non-null  object
#  12  cancellation_policy             29602 non-null  object
#  13  room type                       29602 non-null  object
#  14  Construction year               29602 non-null  int64
#  15  price_$                         29602 non-null  float64
#  16  service_fee_$                   29602 non-null  float64
#  17  minimum nights                  29602 non-null  float64
#  18  number of reviews               29602 non-null  float64
#  19  last review                     29602 non-null  datetime64[ns]
#  20  reviews per month               29602 non-null  float64
#  21  review rate number              29602 non-null  float64
#  22  calculated host listings count  29602 non-null  float64
#  23  availability 365                29602 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(12)
# memory usage: 5.6+ MB

# %%
hood_group= df['neighbourhood group'].value_counts().to_frame()
hood_group
# Out:
#                      count
# neighbourhood group
# Brooklyn             12912
# Manhattan            12577
# Queens                3276
# Bronx                  613
# Staten Island          223
# brookln                  1

# %%
hood_group_bar= plt.bar(hood_group.index, hood_group.loc[:, "count"]);

plt.bar_label(hood_group_bar, labels= hood_group.loc[:, "count"], padding = 4);

plt.ylim([0,40000]);

plt.xlabel('Neighborhood Groups');

plt.ylabel('Number of Listings');

# %%
avg_price= df.groupby('neighbourhood group') ['price_$'].mean().sort_values(ascending = False).to_frame()

avg_price_bar=plt.bar(avg_price.index, avg_price.loc[:, 'price_$']);

plt.bar_label(avg_price_bar, labels = round(avg_price.loc[:,"price_$"], 2), label_type='edge', padding = 43);

plt.ylim([0,700]);

plt.xlabel('Neighborhood Group');

plt.ylabel('Average Price per Listings ($)');

plt.xticks(rotation= 45);
plt.title('Average Price per Listings ($) in each Neighborhood Group');

# %%
df.groupby (df['Construction year']) ['price_$'].mean().to_frame().plot();

plt.xlabel('construction Year');

plt.ylabel('Average Price ($)');

plt.title("Average Price ($) for Properties in each Construction Year");

# %%
hosts = (
    df.groupby('host name')['calculated host listings count']
    .sum()
    .sort_values(ascending=False)
    .nlargest(10)
    .to_frame()
)

hosts_bar = plt.bar(hosts.index, hosts['calculated host listings count'])
plt.bar_label(hosts_bar, labels=hosts['calculated host listings count'], label_type='edge', padding=3)
plt.xlabel("Host Name")
plt.ylabel("Calculated Host Listings Count")
plt.xticks(rotation=30, ha='right')   # rotate for readability
plt.ylim([0, 120000])
plt.title("Top 10 Hosts by Calculated Host Listings Count")
plt.show()
